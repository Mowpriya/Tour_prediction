# %% [markdown]
# ## Problem Statement:
# #### We have a dataset that depicts the rate of trips taken by people based on some features like Age, gender, occupation,monthly income and so on.
# #### We will create a model that can predict whether a person will take the trip or not.

# %% [markdown]
# ## Source of Dataset
# #### We collected the dataset from Kaggle.com
# ## Size of Dataset
# #### Size of Tour Package dataset is 58.9KB

# %% [markdown]
# ## About the Dataset
# #### Tour Package Dataset contains a sample of data giving an overview of the people who went on a trip or not.
# #### Dataset contains 20 columns namely-'CustomerID','ProdTaken','Age','TypeofContact','CityTier','DurationOfPitch','Occupation','Gender','NumberOfPersonVisiting','NumberOfFollowups','ProductPitched','PreferredPropertyStar','MaritalStatus', 'NumberOfTrips','Passport','PitchSatisfactionScore','OwnCar','NumberOfChildrenVisiting','Designation','MonthlyIncome'

# %% [markdown]
# ## Libraries Used
# #### Numpy
# #### Pandas
# #### Matplotlib
# #### Seaborn
# #### Sklearn

# %% [markdown]
# ## Categories
# #### In this dataset, we have both categorical and non-categorical features.
# ### Categorical Columns
# #### Gender,MaritalStatus,TypeofContact,Designation,Occupation,ProductPitched,ProdTaken,CityTier,PreferredPropertyStar,PitchSatisfactionScore,Passport,OwnCar
# ### Non-Categorical Columns
# #### Below Features are non-categorical:
# #### Age,MonthlyIncome,DurationOfPitch,NumberOfPersonVisiting,NumberOfFollowups,NumberOfChildrenVisiting,NumberOfTrips

# %% [markdown]
# ## Overview of the features
# #### Gender- Gender of the person being contacted for taking a trip
# #### MaritalStatus- Marital Status of the person being contacted for taking a trip
# #### Typeofcontact- Mode of Contact
# #### Designation- Designation of the person being contacted for taking a trip
# #### Occupation- Occupation of the person being contacted for taking a trip
# #### ProductPitched- Type of Product pitched to the customers.
# #### ProdTaken- This column has two values 0 and 1. If contacted person takes the trip then its 1 else its 0.
# #### CityTier- CityTier the customer belongs to
# #### PreferredPropertyStar- This column contains information of type of Property Star prefrred by customers.
# #### PitchSatisfcationScore- The feedback score given by teh customers for the product pitch.
# #### Passport- This column gives information of whether customer has a passport or not
# #### OwnCar- This column tells us whether customers owns a car or not.
# #### Age- Age of each person they contacted.
# #### MonthlyIncome- Monthly Income of the all the persons who were contacted for taking a trip.
# #### DurationOfPitch- Duration of Pitch for each product
# #### NunberOFPersonVisiting- Total number of person visiting
# #### NunberOFFollowups- total number of followups¶
# #### NumberOfChildrenVisiting- Total number of children visiting
# #### NumberOfTrips- Nunber of trips taken by each person

# %% [markdown]
# ## Importing required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the dataset

# %%
df=pd.read_csv('tour_package.csv')

# %%
df
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %% [markdown]
# ## Creating a Copy of the dataframe so that we can keep the original dataframe unchanged

# %%
d=df.copy()

# %%
d
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %% [markdown]
# ## Viewing first 5 rows of the dataset

# %%
d.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %% [markdown]
# ## Columns in dataset

# %%
d.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %% [markdown]
# ## Type of data in each column

# %%
d.dtypes
# Out:
# CustomerID                    int64
# ProdTaken                     int64
# Age                         float64
# TypeofContact                object
# CityTier                      int64
# DurationOfPitch             float64
# Occupation                   object
# Gender                       object
# NumberOfPersonVisiting        int64
# NumberOfFollowups           float64
# ProductPitched               object
# PreferredPropertyStar       float64
# MaritalStatus                object
# NumberOfTrips               float64
# Passport                      int64
# PitchSatisfactionScore        int64
# OwnCar                        int64
# NumberOfChildrenVisiting    float64
# Designation                  object
# MonthlyIncome               float64
# dtype: object

# %% [markdown]
# ## Stats of the data in the dataset

# %%
d.describe()
# Out:
#           CustomerID    ProdTaken          Age     CityTier  DurationOfPitch  \
# count    4888.000000  4888.000000  4662.000000  4888.000000      4637.000000
# mean   202443.500000     0.188216    37.622265     1.654255        15.490835
# std      1411.188388     0.390925     9.316387     0.916583         8.519643
# min    200000.000000     0.000000    18.000000     1.000000         5.000000
# 25%    201221.750000     0.000000    31.000000     1.000000         9.000000
# 50%    202443.500000     0.000000    36.000000     1.000000        13.000000
# 75%    203665.250000     0.000000    44.000000     3.000000        20.000000
# max    204887.000000     1.000000    61.000000     3.000000       127.000000
#
#        NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# count             4888.000000        4843.000000            4862.000000
# mean                 2.905074           3.708445               3.581037
# ...

# %% [markdown]
# ## detailed overview of the data

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %% [markdown]
# ## Three random sample

# %%
d.sample(3)
# Out:
#       CustomerID  ProdTaken   Age TypeofContact  CityTier  DurationOfPitch  \
# 2057      202057          0  52.0  Self Enquiry         1             17.0
# 4595      204595          0  39.0  Self Enquiry         1              7.0
# 625       200625          0  45.0  Self Enquiry         3             15.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 2057        Salaried  Female                       2                3.0
# 4595  Large Business  Female                       4                4.0
# 625   Small Business    Male                       3                3.0
#
#      ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 2057         Deluxe                    3.0       Married            1.0
# 4595       Standard                    5.0       Married            3.0
# 625        Standard                    5.0       Married            5.0
#
#       Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# ...

# %% [markdown]
# ## Correlation between target column and numerical columns

# %%
plt.figure(figsize=(15,10))
sns.heatmap(d.iloc[:,[0,1,2,4,5,8,9,11,13,14,15,16,17,19]].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## dropping columns that are not required

# %%
d.drop(['CustomerID','OwnCar','MonthlyIncome','NumberOfChildrenVisiting'],axis=1 ,inplace=True)

# %%
d.shape
# Out:
# (4888, 16)

# %% [markdown]
# ## Handling Missing value and Duplicates

# %%
(d.isnull().sum()/len(d))*100
# Out:
# ProdTaken                 0.000000
# Age                       4.623568
# TypeofContact             0.511457
# CityTier                  0.000000
# DurationOfPitch           5.135025
# Occupation                0.000000
# Gender                    0.000000
# NumberOfPersonVisiting    0.000000
# NumberOfFollowups         0.920622
# ProductPitched            0.000000
# PreferredPropertyStar     0.531915
# MaritalStatus             0.000000
# NumberOfTrips             2.864157
# Passport                  0.000000
# PitchSatisfactionScore    0.000000
# Designation               0.000000
# dtype: float64

# %%
f = plt.figure(figsize=(10,4))
h = sns.heatmap(d.isnull(),cbar=True,cmap='BuPu')

# %%
a=['Age','DurationOfPitch','NumberOfTrips']
for i in a:
    d[i].fillna(d[i].median(),inplace=True)

# %%
d.dropna(inplace=True)

# %%
(d.isnull().sum()/len(d))*100
# Out:
# ProdTaken                 0.0
# Age                       0.0
# TypeofContact             0.0
# CityTier                  0.0
# DurationOfPitch           0.0
# Occupation                0.0
# Gender                    0.0
# NumberOfPersonVisiting    0.0
# NumberOfFollowups         0.0
# ProductPitched            0.0
# PreferredPropertyStar     0.0
# MaritalStatus             0.0
# NumberOfTrips             0.0
# Passport                  0.0
# PitchSatisfactionScore    0.0
# Designation               0.0
# dtype: float64

# %%
d.duplicated().sum()
# Out:
# 583

# %%
d.drop_duplicates(keep='first',inplace=True)

# %%
d.duplicated().sum()
# Out:
# 0

# %%
d.shape
# Out:
# (4209, 16)

# %% [markdown]
# ## Data Preprocessing

# %%
for i in d:
    print(i,'\n')
    print(d[i].unique(),'\n')
    print('===================================')
# Out:
# ProdTaken
#
# [1 0]
#
# ...
# Age
#
# [41. 49. 37. 33. 36. 32. 59. 30. 38. 35. 31. 34. 28. 29. 22. 53. 21. 42.
#  44. 46. 39. 24. 43. 50. 27. 26. 48. 55. 45. 56. 23. 51. 40. 54. 58. 20.
#  25. 19. 57. 52. 47. 18. 60. 61.]
#
# ...
# TypeofContact
#
# ['Self Enquiry' 'Company Invited']
#
# ...
# CityTier
#
# [3 1 2]
#
# ...
# DurationOfPitch
#
# [  6.  14.   8.   9.  30.  29.  33.  22.  21.  32.  25.  27.  11.  17.
#   15.  13.  12.  16.  10.  31.  18.  24.  35.  28.  26.  34.  20.  23.
#    5.  19. 126.   7.  36. 127.]
#
# ...
# Occupation
#
# ['Salaried' 'Free Lancer' 'Small Business' 'Large Business']
#
# ...
# Gender
#
# ['Female' 'Male' 'Fe Male']
#
# ...
# NumberOfPersonVisiting
#
# [3 2 1 4 5]
#
# ...
# NumberOfFollowups
#
# [3. 4. 2. 5. 1. 6.]
#
# ...
# ProductPitched
#
# ['Deluxe' 'Basic' 'Standard' 'Super Deluxe' 'King']
#
# ...
# PreferredPropertyStar
#
# [3. 4. 5.]
#
# ...
# MaritalStatus
#
# ['Single' 'Divorced' 'Married' 'Unmarried']
#
# ...
# NumberOfTrips
#
# [ 1.  2.  7.  5.  6.  3.  4. 19. 21.  8. 20. 22.]
#
# ...
# Passport
#
# [1 0]
#
# ...

# %%
d.replace({'Fe Male':'Female'},inplace=True)

# %%
d.replace({'Unmarried':'Single'},inplace=True)

# %%
cat_col=['Gender','MaritalStatus','TypeofContact','Designation','Occupation','ProductPitched']
c=['ProdTaken','CityTier','PreferredPropertyStar','PitchSatisfactionScore','Passport']

# %%
for i in cat_col:
    print(df[i].value_counts(),'\n')
    print('===========================================')
# Out:
# Gender
# Male       2916
# Female     1817
# Fe Male     155
# Name: count, dtype: int64
#
# ...
# MaritalStatus
# Married      2340
# Divorced      950
# Single        916
# Unmarried     682
# Name: count, dtype: int64
#
# ...
# TypeofContact
# Self Enquiry       3444
# Company Invited    1419
# Name: count, dtype: int64
#
# ...
# Designation
# Executive         1842
# Manager           1732
# Senior Manager     742
# AVP                342
# VP                 230
# Name: count, dtype: int64
#
# ...
# Occupation
# Salaried          2368
# Small Business    2084
# Large Business     434
# Free Lancer          2
# Name: count, dtype: int64
#
# ...
# ProductPitched
# Basic           1842
# Deluxe          1732
# Standard         742
# Super Deluxe     342
# King             230
# Name: count, dtype: int64
#
# ...

# %%
for j in c:
    print(d[j].value_counts(),'\n')
    print('===============================================')
# Out:
# ProdTaken
# 0    3432
# 1     777
# Name: count, dtype: int64
#
# ...
# CityTier
# 1    2724
# 3    1311
# 2     174
# Name: count, dtype: int64
#
# ...
# PreferredPropertyStar
# 3.0    2579
# 5.0     839
# 4.0     791
# Name: count, dtype: int64
#
# ...
# PitchSatisfactionScore
# 3    1202
# 1     927
# 5     761
# 4     744
# 2     575
# Name: count, dtype: int64
#
# ...
# Passport
# 0    2980
# 1    1229
# Name: count, dtype: int64
#
# ...

# %%
df.drop(d[d['Occupation']=='Free Lancer'].index,axis=0,inplace=True)

# %%
df['Occupation'].value_counts()
# Out:
# Occupation
# Salaried          2368
# Small Business    2084
# Large Business     434
# Name: count, dtype: int64

# %%
num_col=['Age','DurationOfPitch','NumberOfPersonVisiting','NumberOfFollowups','NumberOfTrips']

# %%
for k in num_col:
    print(d[k].value_counts(),'\n')
    print('============================================')
# Out:
# Age
# 36.0    396
# 35.0    200
# 30.0    177
# 34.0    175
# 31.0    171
# 32.0    167
# 33.0    162
# 37.0    161
# 29.0    155
# 38.0    153
# 39.0    137
# 40.0    131
# 41.0    129
# 28.0    126
# 42.0    120
# 27.0    117
# 43.0    113
# 46.0    107
# 45.0    100
# 44.0     90
# 26.0     89
# 47.0     77
# 51.0     77
# 50.0     76
# 25.0     65
# 52.0     60
# 55.0     59
# 48.0     59
# 49.0     59
# 53.0     57
# 54.0     56
# 56.0     48
# 24.0     48
# 23.0     45
# 22.0     39
# 59.0     37
# 21.0     29
# 58.0     27
# 20.0     25
# 19.0     24
# 60.0     24
# 57.0     23
# 18.0     12
# 61.0      7
# Name: count, dtype: int64
#
# ...
# DurationOfPitch
# 9.0      421
# 13.0     395
# 7.0      302
# 8.0      288
# 6.0      273
# 15.0     232
# 16.0     225
# 14.0     220
# 10.0     209
# 11.0     174
# 12.0     164
# 17.0     139
# 30.0      78
# 22.0      77
# 23.0      69
# 31.0      69
# 27.0      67
# 26.0      67
# 18.0      66
# 32.0      66
# 29.0      64
# 21.0      64
# ...

# %%
d.drop(d[d['DurationOfPitch']==126.0].index,axis=0,inplace=True)

# %%
d.drop(d[d['DurationOfPitch']==127.0].index,axis=0,inplace=True)

# %%
d['DurationOfPitch'].value_counts()
# Out:
# DurationOfPitch
# 9.0     421
# 13.0    395
# 7.0     302
# 8.0     288
# 6.0     273
# 15.0    232
# 16.0    225
# 14.0    220
# 10.0    209
# 11.0    174
# 12.0    164
# 17.0    139
# 30.0     78
# 22.0     77
# 31.0     69
# 23.0     69
# 27.0     67
# 26.0     67
# 32.0     66
# 18.0     66
# 21.0     64
# 29.0     64
# 25.0     64
# 24.0     61
# 35.0     57
# 28.0     56
# 19.0     53
# 20.0     52
# 33.0     50
# 34.0     45
# 36.0     34
# 5.0       6
# Name: count, dtype: int64

# %%
d.drop(d[d['NumberOfPersonVisiting']==5].index,axis=0,inplace=True)

# %%
d['NumberOfPersonVisiting'].value_counts()
# Out:
# NumberOfPersonVisiting
# 3    2078
# 2    1196
# 4     896
# 1      34
# Name: count, dtype: int64

# %%
d.drop(d[d['NumberOfTrips']==19].index,axis=0,inplace=True)

# %%
d.drop(df[df['NumberOfTrips']==20].index,axis=0,inplace=True)

# %%
d.drop(df[df['NumberOfTrips']==21].index,axis=0,inplace=True)

# %%
d.drop(df[df['NumberOfTrips']==22].index,axis=0,inplace=True)

# %%
d['NumberOfTrips'].value_counts()
# Out:
# NumberOfTrips
# 2.0    1259
# 3.0    1050
# 1.0     520
# 4.0     423
# 5.0     392
# 6.0     281
# 7.0     188
# 8.0      87
# Name: count, dtype: int64

# %% [markdown]
# ## Handling catgorical Columns

# %%
d=pd.get_dummies(d,drop_first=True)
d
# Out:
#       ProdTaken   Age  CityTier  DurationOfPitch  NumberOfPersonVisiting  \
# 0             1  41.0         3              6.0                       3
# 1             0  49.0         1             14.0                       3
# 2             1  37.0         1              8.0                       3
# 3             0  33.0         1              9.0                       2
# 4             0  36.0         1              8.0                       2
# ...         ...   ...       ...              ...                     ...
# 4883          1  49.0         3              9.0                       3
# 4884          1  28.0         1             31.0                       4
# 4885          1  52.0         3             17.0                       4
# 4886          1  19.0         3             16.0                       3
# 4887          1  36.0         1             14.0                       4
#
#       NumberOfFollowups  PreferredPropertyStar  NumberOfTrips  Passport  \
# ...

# %% [markdown]
# ## Separating x and y from dataset

# %%
x=d.drop('ProdTaken',axis=1)
y=d['ProdTaken']

# %%
x
# Out:
#        Age  CityTier  DurationOfPitch  NumberOfPersonVisiting  \
# 0     41.0         3              6.0                       3
# 1     49.0         1             14.0                       3
# 2     37.0         1              8.0                       3
# 3     33.0         1              9.0                       2
# 4     36.0         1              8.0                       2
# ...    ...       ...              ...                     ...
# 4883  49.0         3              9.0                       3
# 4884  28.0         1             31.0                       4
# 4885  52.0         3             17.0                       4
# 4886  19.0         3             16.0                       3
# 4887  36.0         1             14.0                       4
#
#       NumberOfFollowups  PreferredPropertyStar  NumberOfTrips  Passport  \
# 0                   3.0                    3.0            1.0         1
# 1                   4.0                    4.0            2.0         0
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 4883    1
# 4884    1
# 4885    1
# 4886    1
# 4887    1
# Name: ProdTaken, Length: 4200, dtype: int64

# %% [markdown]
# ## Train-test-Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
x_train
# Out:
# array([[-1.07511273,  1.47410992, -1.04045655, ...,  1.34164079,
#         -0.4346949 , -0.21313437],
#        [ 0.36012334,  1.47410992, -0.79123652, ..., -0.74535599,
#         -0.4346949 ,  4.69187581],
#        [-0.41269608, -0.71264917, -0.91584653, ...,  1.34164079,
#         -0.4346949 , -0.21313437],
#        ...,
#        [ 1.13294276, -0.71264917, -1.04045655, ..., -0.74535599,
#         -0.4346949 , -0.21313437],
#        [-0.85430718, -0.71264917, -0.04357642, ..., -0.74535599,
#         -0.4346949 , -0.21313437],
#        [-0.30229331,  1.47410992, -0.16818644, ..., -0.74535599,
#          2.30046405, -0.21313437]])

# %%
x_test
# Out:
# array([[-0.52309886, -0.71264917, -1.16506656, ..., -0.74535599,
#         -0.4346949 , -0.21313437],
#        [-1.29591828, -0.71264917, -0.16818644, ..., -0.74535599,
#         -0.4346949 , -0.21313437],
#        [ 0.91213721,  1.47410992,  0.0810336 , ..., -0.74535599,
#          2.30046405, -0.21313437],
#        ...,
#        [-0.96470996, -0.71264917,  0.0810336 , ..., -0.74535599,
#         -0.4346949 , -0.21313437],
#        [-0.52309886, -0.71264917, -1.04045655, ...,  1.34164079,
#         -0.4346949 , -0.21313437],
#        [ 1.3537483 , -0.71264917, -1.16506656, ..., -0.74535599,
#         -0.4346949 ,  4.69187581]])

# %% [markdown]
# ## Model building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
lr=LogisticRegression(random_state=0)
tree= DecisionTreeClassifier(random_state=0)
forest= RandomForestClassifier(random_state=0)
knn= KNeighborsClassifier(n_neighbors=5,metric='minkowski',p=2)
svm= SVC(kernel='linear',random_state=0)
nb=GaussianNB()

models= [lr,tree, forest, knn, svm, nb]

for model in models:
    model.fit(x_train, y_train) 
    y_pred= model.predict(x_test) 
    accuracy= accuracy_score(y_test, y_pred)
    con_mat=confusion_matrix(y_test,y_pred)
    clf_report= classification_report(y_test, y_pred)
    print(f"The accuracy of model {type(model).__name__} is {accuracy:.2f}")
    print('Training Score:',100*model.score(x_train,y_train))
    print(con_mat)
    print(clf_report)
    print("\n")
# Out:
# The accuracy of model LogisticRegression is 0.85
# Training Score: 84.61309523809524
# [[669  24]
#  [102  45]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.91       693
#            1       0.65      0.31      0.42       147
#
#     accuracy                           0.85       840
#    macro avg       0.76      0.64      0.67       840
# weighted avg       0.83      0.85      0.83       840
#
#
#
# The accuracy of model DecisionTreeClassifier is 0.91
# Training Score: 100.0
# [[648  45]
#  [ 27 120]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       693
#            1       0.73      0.82      0.77       147
#
#     accuracy                           0.91       840
#    macro avg       0.84      0.88      0.86       840
# weighted avg       0.92      0.91      0.92       840
#
#
#
# The accuracy of model RandomForestClassifier is 0.95
# ...

# %% [markdown]
# ## Feature selection

# %%
ft = tree.feature_importances_

# %%
ft
# Out:
# array([1.43591915e-01, 5.63387136e-02, 1.79270277e-01, 2.30111931e-02,
#        3.79888270e-02, 5.23185082e-02, 7.84788159e-02, 6.74083655e-02,
#        8.49685314e-02, 3.73377997e-02, 1.58777189e-02, 1.46492774e-02,
#        3.00148865e-02, 2.22574410e-02, 8.61248206e-03, 0.00000000e+00,
#        3.32582536e-03, 5.82350656e-05, 4.58697004e-03, 4.30926935e-02,
#        8.32099092e-02, 2.85855448e-03, 1.07430602e-02, 0.00000000e+00])

# %%
imp = pd.Series(ft,index=x.columns).sort_values()
plt.figure(figsize=(5,10))
imp.plot.barh()
plt.show()

# %%
x=d[['DurationOfPitch','Age','PitchSatisfactionScore','Designation_Executive','NumberOfTrips','Passport','PreferredPropertyStar','CityTier']]
y=d['ProdTaken']

# %%
from sklearn.model_selection import train_test_split
x_trn,x_tst,y_trn,y_tst=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_trn=sc.fit_transform(x_trn)
x_tst=sc.transform(x_tst)

# %%
x_trn
# Out:
# array([[-1.04045655, -1.07511273, -0.69659425, ...,  1.54281616,
#          0.50767002,  1.47410992],
#        [-0.79123652,  0.36012334,  0.02357704, ..., -0.64816537,
#         -0.73741849,  1.47410992],
#        [-0.91584653, -0.41269608,  0.74374832, ..., -0.64816537,
#          1.75275852, -0.71264917],
#        ...,
#        [-1.04045655,  1.13294276,  0.02357704, ..., -0.64816537,
#         -0.73741849, -0.71264917],
#        [-0.04357642, -0.85430718,  0.02357704, ...,  1.54281616,
#          1.75275852, -0.71264917],
#        [-0.16818644, -0.30229331,  1.4639196 , ...,  1.54281616,
#         -0.73741849,  1.47410992]])

# %%
x_tst
# Out:
# array([[-1.16506656, -0.52309886, -1.41676553, ..., -0.64816537,
#         -0.73741849, -0.71264917],
#        [-0.16818644, -1.29591828, -0.69659425, ..., -0.64816537,
#         -0.73741849, -0.71264917],
#        [ 0.0810336 ,  0.91213721, -1.41676553, ...,  1.54281616,
#         -0.73741849,  1.47410992],
#        ...,
#        [ 0.0810336 , -0.96470996,  0.02357704, ..., -0.64816537,
#         -0.73741849, -0.71264917],
#        [-1.04045655, -0.52309886,  0.74374832, ...,  1.54281616,
#         -0.73741849, -0.71264917],
#        [-1.16506656,  1.3537483 , -0.69659425, ...,  1.54281616,
#          0.50767002, -0.71264917]])

# %%
models = []
models.append(('LogisticRegression',LogisticRegression(solver='liblinear')))
models.append(('Naive bayes' ,GaussianNB()))
models.append(('RandomForest' ,RandomForestClassifier()))
models.append(('Decision Tree ' ,DecisionTreeClassifier()))
models.append(('SVM',SVC()))
models.append (('KNN' ,KNeighborsClassifier()))

# %%
for name, model in models:
    print(name)
    model.fit(x_trn , y_trn)
    prediction = model.predict(x_tst) 
    print('Training Score:',100*model.score(x_trn,y_trn))
    print('Accuracy Score: ' + str(accuracy_score(prediction,y_tst)))
    print('_________________________')
    print('Confusion Matrix:\n ' + str(confusion_matrix(prediction,y_tst)))
    print('_________________________')
    print('Classification Report:\n ' + str(classification_report(prediction,y_tst)))
    print('==========================================================================')
# Out:
# LogisticRegression
# Training Score: 83.86904761904762
# Accuracy Score: 0.8511904761904762
# _________________________
# Confusion Matrix:
#  [[680 112]
#  [ 13  35]]
# _________________________
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.86      0.92       792
#            1       0.24      0.73      0.36        48
#
#     accuracy                           0.85       840
#    macro avg       0.61      0.79      0.64       840
# weighted avg       0.94      0.85      0.88       840
#
# ...
# Naive bayes
# Training Score: 83.95833333333333
# Accuracy Score: 0.8511904761904762
# _________________________
# Confusion Matrix:
#  [[675 107]
#  [ 18  40]]
# _________________________
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.86      0.92       782
#            1       0.27      0.69      0.39        58
#
# ...

# %% [markdown]
# ### Grid Search HyperParameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
params_dt = {'criterion':['gini','entropy'],
            'max_depth':[1,2,3,4,5,6,7,None],
            'min_samples_split':[2,4,6,8,10]}

# %%
model_grid = GridSearchCV(DecisionTreeClassifier(),param_grid=params_dt,verbose = 3).fit(x_trn,y_trn)
model_grid
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_split=2;, score=0.814 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_split=2;, score=0.814 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_split=2;, score=0.812 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_split=2;, score=0.812 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, min_samples_split=2;, score=0.812 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, min_samples_split=4;, score=0.814 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, min_samples_split=4;, score=0.814 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, min_samples_split=4;, score=0.812 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, min_samples_split=4;, score=0.812 total time=   0.0s
# ...

# %%
model_grid.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': None, 'min_samples_split': 2}

# %%
model_grid.best_score_
# Out:
# 0.8699404761904763

# %% [markdown]
# ## Testing the model with Test data

# %%
pred=model_grid.predict(np.array([[10,30,5,True,1,1,4,2]])).reshape(1)
print(pred)
# Out:
# [0]
